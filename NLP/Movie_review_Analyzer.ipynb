# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# # Goal is to classify if the review is positive or negative

# %%
corpus = [
    "the movie was fantastic and i loved every part of it",
    "an absolute masterpiece with brilliant acting",
    "i really enjoyed the story and the visuals",
    "what a wonderful experience, highly recommend",
    "a truly great film, i will watch it again",
    "an amazing journey from start to finish",
    "the plot was exciting and very engaging",
    "i loved the characters and the dialogue",
    "a remarkable and touching performance",
    "this film was heartwarming and inspiring",
    "the film was boring and too long",
    "the plot was terrible and the acting was even worse",
    "not worth my time, very disappointing",
    "the script was weak and the characters were flat",
    "a boring and bad story",
    "i hated the film",
    "an awful movie with poor performances",
    "the storyline was confusing and dull",
    "completely uninteresting and forgettable",
    "a disappointing and frustrating experience"

]

# %%
labels = [
    "Positive","Positive","Positive","Positive","Positive",
    "Positive","Positive","Positive","Positive","Positive",
    "Negative","Negative","Negative","Negative","Negative",
    "Negative","Negative","Negative","Negative","Negative"
]

# %%
# A vectorizer is a tool or algorithm that converts data from one format into a structured,
# numerical format known as a "vector

vectorizer = CountVectorizer(stop_words = 'english' , ngram_range=(1, 3))

# %%
# here fit() learns the vocublary from corpus and transform() converts the corpus into a vectorized format

vectors = vectorizer.fit_transform(corpus)
print("Feature names:", vectorizer.get_feature_names_out())
print("Vectors shape:", vectors.toarray())
# Out:
# Feature names: ['absolute' 'absolute masterpiece' 'absolute masterpiece brilliant'
#  'acting' 'acting worse' 'amazing' 'amazing journey'
#  'amazing journey start' 'awful' 'awful movie' 'awful movie poor' 'bad'
#  'bad story' 'boring' 'boring bad' 'boring bad story' 'boring long'
#  'brilliant' 'brilliant acting' 'characters' 'characters dialogue'
#  'characters flat' 'completely' 'completely uninteresting'
#  'completely uninteresting forgettable' 'confusing' 'confusing dull'
#  'dialogue' 'disappointing' 'disappointing frustrating'
#  'disappointing frustrating experience' 'dull' 'engaging' 'enjoyed'
#  'enjoyed story' 'enjoyed story visuals' 'exciting' 'exciting engaging'
#  'experience' 'experience highly' 'experience highly recommend'
#  'fantastic' 'fantastic loved' 'film' 'film boring' 'film boring long'
#  'film heartwarming' 'film heartwarming inspiring' 'film watch' 'finish'
#  'flat' 'forgettable' 'frustrating' 'frustrating experience' 'great'
# ...

# %% [markdown]
# fit() -Purpose: Learn the parameters/statistics from the data.\n
# transform() :Purpose: Actually apply the learned parameters to your data.
# fit_transform() Shortcut: Combines fit() + transform() in one line.

# %%
model = SVC(kernel ='linear')
model.fit(vectors, labels)  # fit() is used to train the model on the provided data
# Out:
# SVC(kernel='linear')

# %%
# Test the model with a new review
test_corpus = [
    "the movie was great",
    "i hated that film",
    "a boring and bad story",
    "absolutely loved it",
    "movie is not good",
    "Oh wow, the sequel is exactly the same as the first one. Original",
    "the acting was not bad",
    "visually impressive but boring",
    "i wanted to like it"
]

# %%
 # we use transform() to convert the test corpus into the same vectorized format as the training data
 # we dont use fit() here because we dont want to learn a new vocabulary from the test data, we want to use the same vocabulary learned from the training data

test_vectors = vectorizer.transform(test_corpus)
predictions = model.predict(test_vectors)

# %%
for text,pred in zip(test_corpus, predictions):
    print(f"Review: '{text}' => Sentiment: {pred}")
# Out:
# Review: 'the movie was great' => Sentiment: Positive
# Review: 'i hated that film' => Sentiment: Negative
# Review: 'a boring and bad story' => Sentiment: Negative
# Review: 'absolutely loved it' => Sentiment: Positive
# Review: 'movie is not good' => Sentiment: Negative
# Review: 'Oh wow, the sequel is exactly the same as the first one. Original' => Sentiment: Negative
# Review: 'the acting was not bad' => Sentiment: Negative
# Review: 'visually impressive but boring' => Sentiment: Negative
# Review: 'i wanted to like it' => Sentiment: Negative

# %% [markdown]
# using countvectorizer has a drawback : Words like "hated", "boring", "disappointing" in your test set may not appear enough in training or may be ignored because the vectorizer only counts occurrences in training vocabulary.
#
# If negative words are missing or rare in training, the SVM sees very sparse vectors, making it think the review is Positive.

# %% [markdown]
# # using tfidf vectorizer

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,3),stop_words = 'english')
vectors = vectorizer.fit_transform(corpus)

# %%
model2 = SVC(kernel ='linear')
model2.fit(vectors, labels)  # fit() is used to train the model on the provided data
# Out:
# SVC(kernel='linear')

# %%
test_vectors = vectorizer.transform(test_corpus)
predictions = model2.predict(test_vectors)

# %%
for text,pred in zip(test_corpus, predictions):
    print(f"Review: '{text}' => Sentiment: {pred}")
# Out:
# Review: 'the movie was great' => Sentiment: Positive
# Review: 'i hated that film' => Sentiment: Negative
# Review: 'a boring and bad story' => Sentiment: Negative
# Review: 'absolutely loved it' => Sentiment: Positive
# Review: 'movie is not good' => Sentiment: Positive
# Review: 'Oh wow, the sequel is exactly the same as the first one. Original' => Sentiment: Positive
# Review: 'the acting was not bad' => Sentiment: Negative
# Review: 'visually impressive but boring' => Sentiment: Negative
# Review: 'i wanted to like it' => Sentiment: Positive

# %% [markdown]
# What is the main limitation of representing text using only word counts?
# Why might a model that understands word context perform better?
# What kinds of problems in language might require more advanced NLP model
#
# 1. <p>if we only use word counts the sentence is treated as bag of words -> cannot understand word relations , context (this movie is good )(this movie is not good ) both have good so model predicts positive </p></br>
# 2. <p> the model understands context so it can understand the word relations (good -> not good ) sarcasm and other stuff </p></br>
